# %%
import os
import sys
import datetime
import pandas as pd
import numpy as np
import config
import random
df = pd.read_csv('input_data.csv')
df
# Out:
#    one  two  three   four   five         six    seven eight
# 0  NaN  2.1    3.1    bar   True         NaN  £200.45   BMC
# 1  NaN  NaN    3.2    NaN  False  01/01/2017  £650.38   ACS
# 2  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.4    NaN    bar    NaN  03/01/2017      NaN   BPS
# 4  NaN  2.5    3.5    bar  False         NaN  £230.22   BMC
# 5  6.0  NaN    3.3   club   True  02/01/2017  £650.96   CJS
# 6  2.0  2.5    NaN  house    NaN  04/01/2017      NaN    FM
# 7  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS

# %%
print(df.shape)
# Out:
# (8, 8)

# %%
df.info
# Out:
# <bound method DataFrame.info of    one  two  three   four   five         six    seven eight
# 0  NaN  2.1    3.1    bar   True         NaN  £200.45   BMC
# 1  NaN  NaN    3.2    NaN  False  01/01/2017  £650.38   ACS
# 2  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.4    NaN    bar    NaN  03/01/2017      NaN   BPS
# 4  NaN  2.5    3.5    bar  False         NaN  £230.22   BMC
# 5  6.0  NaN    3.3   club   True  02/01/2017  £650.96   CJS
# 6  2.0  2.5    NaN  house    NaN  04/01/2017      NaN    FM
# 7  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     5 non-null      float64
#  1   two     6 non-null      float64
#  2   three   6 non-null      float64
#  3   four    7 non-null      object
#  4   five    6 non-null      object
#  5   six     6 non-null      object
#  6   seven   6 non-null      object
#  7   eight   8 non-null      object
# dtypes: float64(3), object(5)
# memory usage: 640.0+ bytes

# %%
df.describe()
# Out:
#             one       two     three
# count  5.000000  6.000000  6.000000
# mean   3.800000  2.350000  3.283333
# std    1.643168  0.151658  0.132916
# min    2.000000  2.100000  3.100000
# 25%    3.000000  2.300000  3.225000
# 50%    3.000000  2.350000  3.300000
# 75%    5.000000  2.475000  3.300000
# max    6.000000  2.500000  3.500000

# %%
df['one']
# Out:
# 0    NaN
# 1    NaN
# 2    3.0
# 3    5.0
# 4    NaN
# 5    6.0
# 6    2.0
# 7    3.0
# Name: one, dtype: float64

# %%
df['three']
# Out:
# 0    3.1
# 1    3.2
# 2    3.3
# 3    NaN
# 4    3.5
# 5    3.3
# 6    NaN
# 7    3.3
# Name: three, dtype: float64

# %%
df['three'].value_counts()
# Out:
# three
# 3.3    3
# 3.1    1
# 3.2    1
# 3.5    1
# Name: count, dtype: int64

# %%
df['three'].value_counts(3)
# Out:
# three
# 3.3    0.500000
# 3.1    0.166667
# 3.2    0.166667
# 3.5    0.166667
# Name: proportion, dtype: float64

# %%
df['four'].value_counts()
# Out:
# four
# bar      3
# club     3
# house    1
# Name: count, dtype: int64

# %%
df[['one','two','seven']]
# Out:
#    one  two    seven
# 0  NaN  2.1  £200.45
# 1  NaN  NaN  £650.38
# 2  3.0  2.3   £85.07
# 3  5.0  2.4      NaN
# 4  NaN  2.5  £230.22
# 5  6.0  NaN  £650.96
# 6  2.0  2.5      NaN
# 7  3.0  2.3   £85.07

# %%
data = df[['one','two','seven']]
data['two']>2.3
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6     True
# 7    False
# Name: two, dtype: bool

# %%
data[data['two']>2.3]
# Out:
#    one  two    seven
# 3  5.0  2.4      NaN
# 4  NaN  2.5  £230.22
# 6  2.0  2.5      NaN

# %%
df
# Out:
#    one  two  three   four   five         six    seven eight
# 0  NaN  2.1    3.1    bar   True         NaN  £200.45   BMC
# 1  NaN  NaN    3.2    NaN  False  01/01/2017  £650.38   ACS
# 2  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.4    NaN    bar    NaN  03/01/2017      NaN   BPS
# 4  NaN  2.5    3.5    bar  False         NaN  £230.22   BMC
# 5  6.0  NaN    3.3   club   True  02/01/2017  £650.96   CJS
# 6  2.0  2.5    NaN  house    NaN  04/01/2017      NaN    FM
# 7  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS

# %%
df['one'].isna()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# Name: one, dtype: bool

# %%
df[df['one'].isna()]
# Out:
#    one  two  three four   five         six    seven eight
# 0  NaN  2.1    3.1  bar   True         NaN  £200.45   BMC
# 1  NaN  NaN    3.2  NaN  False  01/01/2017  £650.38   ACS
# 4  NaN  2.5    3.5  bar  False         NaN  £230.22   BMC

# %%
data
# Out:
#    one  two    seven
# 0  NaN  2.1  £200.45
# 1  NaN  NaN  £650.38
# 2  3.0  2.3   £85.07
# 3  5.0  2.4      NaN
# 4  NaN  2.5  £230.22
# 5  6.0  NaN  £650.96
# 6  2.0  2.5      NaN
# 7  3.0  2.3   £85.07

# %%
data.dropna()
# Out:
#    one  two   seven
# 2  3.0  2.3  £85.07
# 7  3.0  2.3  £85.07

# %%
data.drop_duplicates()
# Out:
#    one  two    seven
# 0  NaN  2.1  £200.45
# 1  NaN  NaN  £650.38
# 2  3.0  2.3   £85.07
# 3  5.0  2.4      NaN
# 4  NaN  2.5  £230.22
# 5  6.0  NaN  £650.96
# 6  2.0  2.5      NaN

# %%
df.apply(lambda x: sum(x.isnull()), axis=1)
# Out:
# 0    2
# 1    3
# 2    0
# 3    3
# 4    2
# 5    1
# 6    3
# 7    0
# dtype: int64

# %%
df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# one      3
# two      2
# three    2
# four     1
# five     2
# six      2
# seven    2
# eight    0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#    one  two  three  four  five         six   seven eight
# 7  3.0  2.3    3.3  club  True  02/01/2017  £85.07   ACS

# %%
temp=df.drop_duplicates()
temp
# Out:
#    one  two  three   four   five         six    seven eight
# 0  NaN  2.1    3.1    bar   True         NaN  £200.45   BMC
# 1  NaN  NaN    3.2    NaN  False  01/01/2017  £650.38   ACS
# 2  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.4    NaN    bar    NaN  03/01/2017      NaN   BPS
# 4  NaN  2.5    3.5    bar  False         NaN  £230.22   BMC
# 5  6.0  NaN    3.3   club   True  02/01/2017  £650.96   CJS
# 6  2.0  2.5    NaN  house    NaN  04/01/2017      NaN    FM

# %%
df
# Out:
#    one  two  three   four   five         six    seven eight
# 0  NaN  2.1    3.1    bar   True         NaN  £200.45   BMC
# 1  NaN  NaN    3.2    NaN  False  01/01/2017  £650.38   ACS
# 2  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.4    NaN    bar    NaN  03/01/2017      NaN   BPS
# 4  NaN  2.5    3.5    bar  False         NaN  £230.22   BMC
# 5  6.0  NaN    3.3   club   True  02/01/2017  £650.96   CJS
# 6  2.0  2.5    NaN  house    NaN  04/01/2017      NaN    FM
# 7  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS

# %%
df
# Out:
#    one  two  three   four   five         six    seven eight
# 0  NaN  2.1    3.1    bar   True         NaN  £200.45   BMC
# 1  NaN  NaN    3.2    NaN  False  01/01/2017  £650.38   ACS
# 2  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.4    NaN    bar    NaN  03/01/2017      NaN   BPS
# 4  NaN  2.5    3.5    bar  False         NaN  £230.22   BMC
# 5  6.0  NaN    3.3   club   True  02/01/2017  £650.96   CJS
# 6  2.0  2.5    NaN  house    NaN  04/01/2017      NaN    FM
# 7  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS

# %%
df[df['one'].isna()]
# Out:
#    one  two  three four   five         six    seven eight
# 0  NaN  2.1    3.1  bar   True         NaN  £200.45   BMC
# 1  NaN  NaN    3.2  NaN  False  01/01/2017  £650.38   ACS
# 4  NaN  2.5    3.5  bar  False         NaN  £230.22   BMC

# %%
set=df[df['one'].isna()]
set
# Out:
#    one  two  three four   five         six    seven eight
# 0  NaN  2.1    3.1  bar   True         NaN  £200.45   BMC
# 1  NaN  NaN    3.2  NaN  False  01/01/2017  £650.38   ACS
# 4  NaN  2.5    3.5  bar  False         NaN  £230.22   BMC

# %%
df

# %%
np.mean(df['one'])
# Out:
# 3.8

# %%
df['one'].fillna(np.mean(df['one']),inplace=True)
df
# Out:
# /tmp/ipykernel_15600/1892814720.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['one'].fillna(np.mean(df['one']),inplace=True)
#    one  two  three   four   five         six    seven eight
# 0  3.8  2.1    3.1    bar   True         NaN  £200.45   BMC
# 1  3.8  NaN    3.2    NaN  False  01/01/2017  £650.38   ACS
# 2  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.4    NaN    bar    NaN  03/01/2017      NaN   BPS
# 4  3.8  2.5    3.5    bar  False         NaN  £230.22   BMC
# ...

# %%
df
# Out:
#    one  two  three   four   five         six    seven eight
# 0  3.8  2.1    3.1    bar   True         NaN  £200.45   BMC
# 1  3.8  NaN    3.2    NaN  False  01/01/2017  £650.38   ACS
# 2  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.4    NaN    bar    NaN  03/01/2017      NaN   BPS
# 4  3.8  2.5    3.5    bar  False         NaN  £230.22   BMC
# 5  6.0  NaN    3.3   club   True  02/01/2017  £650.96   CJS
# 6  2.0  2.5    NaN  house    NaN  04/01/2017      NaN    FM
# 7  3.0  2.3    3.3   club   True  02/01/2017   £85.07   ACS

# %%
df['two'].fillna(np.mean(df['two']),inplace=True)
df
# Out:
# /tmp/ipykernel_15600/3722976818.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['two'].fillna(np.mean(df['two']),inplace=True)
#    one   two  three   four   five         six    seven eight
# 0  3.8  2.10    3.1    bar   True         NaN  £200.45   BMC
# 1  3.8  2.35    3.2    NaN  False  01/01/2017  £650.38   ACS
# 2  3.0  2.30    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.40    NaN    bar    NaN  03/01/2017      NaN   BPS
# 4  3.8  2.50    3.5    bar  False         NaN  £230.22   BMC
# ...

# %%
df['three'].fillna(df['three'].median(),inplace=True)
df
# Out:
# /tmp/ipykernel_15600/1923823334.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['three'].fillna(df['three'].median(),inplace=True)
#    one   two  three   four   five         six    seven eight
# 0  3.8  2.10    3.1    bar   True         NaN  £200.45   BMC
# 1  3.8  2.35    3.2    NaN  False  01/01/2017  £650.38   ACS
# 2  3.0  2.30    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.40    3.3    bar    NaN  03/01/2017      NaN   BPS
# 4  3.8  2.50    3.5    bar  False         NaN  £230.22   BMC
# ...

# %%
df['four'] = df['four'].fillna('club')
df
# Out:
#    one   two  three   four   five         six    seven eight
# 0  3.8  2.10    3.1    bar   True         NaN  £200.45   BMC
# 1  3.8  2.35    3.2   club  False  01/01/2017  £650.38   ACS
# 2  3.0  2.30    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.40    3.3    bar    NaN  03/01/2017      NaN   BPS
# 4  3.8  2.50    3.5    bar  False         NaN  £230.22   BMC
# 5  6.0  2.35    3.3   club   True  02/01/2017  £650.96   CJS
# 6  2.0  2.50    3.3  house    NaN  04/01/2017      NaN    FM
# 7  3.0  2.30    3.3   club   True  02/01/2017   £85.07   ACS

# %%
df['five'] = df['five'].fillna(False)
df
# Out:
# /tmp/ipykernel_15600/4263971825.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['five'] = df['five'].fillna(False)
#    one   two  three   four   five         six    seven eight
# 0  3.8  2.10    3.1    bar   True         NaN  £200.45   BMC
# 1  3.8  2.35    3.2   club  False  01/01/2017  £650.38   ACS
# 2  3.0  2.30    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.40    3.3    bar  False  03/01/2017      NaN   BPS
# 4  3.8  2.50    3.5    bar  False         NaN  £230.22   BMC
# 5  6.0  2.35    3.3   club   True  02/01/2017  £650.96   CJS
# 6  2.0  2.50    3.3  house  False  04/01/2017      NaN    FM
# 7  3.0  2.30    3.3   club   True  02/01/2017   £85.07   ACS

# %%
now = datetime.datetime.now()
now
# Out:
# datetime.datetime(2024, 5, 16, 15, 50, 53, 188164)

# %%
now = datetime.datetime.now().strftime("%m/%d/%y")
now
# Out:
# '05/16/24'

# %%
now
# Out:
# '05/16/24'

# %%
df['six']=df['six'].fillna(now)
df
# Out:
#    one   two  three   four   five         six    seven eight
# 0  3.8  2.10    3.1    bar   True    05/16/24  £200.45   BMC
# 1  3.8  2.35    3.2   club  False  01/01/2017  £650.38   ACS
# 2  3.0  2.30    3.3   club   True  02/01/2017   £85.07   ACS
# 3  5.0  2.40    3.3    bar  False  03/01/2017      NaN   BPS
# 4  3.8  2.50    3.5    bar  False    05/16/24  £230.22   BMC
# 5  6.0  2.35    3.3   club   True  02/01/2017  £650.96   CJS
# 6  2.0  2.50    3.3  house  False  04/01/2017      NaN    FM
# 7  3.0  2.30    3.3   club   True  02/01/2017   £85.07   ACS

# %%
print(type(df['six'][0]))
# Out:
# <class 'str'>

# %%
df['six']= pd.to_datetime(df['six'])
df
# Out:
# /tmp/ipykernel_15600/3639058218.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['six']= pd.to_datetime(df['six'])
#    one   two  three   four   five        six    seven eight
# 0  3.8  2.10    3.1    bar   True 2024-05-16  £200.45   BMC
# 1  3.8  2.35    3.2   club  False 2017-01-01  £650.38   ACS
# 2  3.0  2.30    3.3   club   True 2017-02-01   £85.07   ACS
# 3  5.0  2.40    3.3    bar  False 2017-03-01      NaN   BPS
# 4  3.8  2.50    3.5    bar  False 2024-05-16  £230.22   BMC
# 5  6.0  2.35    3.3   club   True 2017-02-01  £650.96   CJS
# 6  2.0  2.50    3.3  house  False 2017-04-01      NaN    FM
# 7  3.0  2.30    3.3   club   True 2017-02-01   £85.07   ACS

# %%
print(type(df['six'][2]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df['seven']=df['seven'].fillna("$100")
df
# Out:
#    one   two  three   four   five        six    seven eight
# 0  3.8  2.10    3.1    bar   True 2024-05-16  £200.45   BMC
# 1  3.8  2.35    3.2   club  False 2017-01-01  £650.38   ACS
# 2  3.0  2.30    3.3   club   True 2017-02-01   £85.07   ACS
# 3  5.0  2.40    3.3    bar  False 2017-03-01     $100   BPS
# 4  3.8  2.50    3.5    bar  False 2024-05-16  £230.22   BMC
# 5  6.0  2.35    3.3   club   True 2017-02-01  £650.96   CJS
# 6  2.0  2.50    3.3  house  False 2017-04-01     $100    FM
# 7  3.0  2.30    3.3   club   True 2017-02-01   £85.07   ACS

# %%
import seaborn as sns
iris_data = sns.load_dataset("iris")

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
